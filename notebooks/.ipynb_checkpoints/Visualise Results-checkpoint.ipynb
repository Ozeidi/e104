# %%
import json
import itertools
from sklearn import preprocessing
from sklearn.externals import joblib
import numpy as np
import pandas as pd
from datetime import datetime as dt
#Visualisation
#import matplotlib
import matplotlib.pyplot as plt
#%matplotlib inline
# %matplotlib notebook
# from pylab import rcParams
# from matplotlib import gridspec
# import seaborn as sns
# from ggplot import *
# import plotly.plotly as py
# #Formatted Print 
# from IPython.display import Markdown, display

#NILMTK
from nilmtk import DataSet
from nilmtk.utils import print_dict
from nilmtk.datastore import HDFDataStore
from nilmtk.electric import align_two_meters



allowed_key_names = ['fridge','microwave','dish_washer','kettle','washing_machine']
WINDOW_PER_BUILDING = {
    1: ("2013-04-12", "2014-12-15"),
    2: ("2013-05-22", "2013-10-03 06:16:00"),
    3: ("2013-02-27", "2013-03-27 06:15:05"),
    4: ("2013-03-09", "2013-04-24 06:15:14"),
    5: ("2014-06-29", "2014-09-01")
}

# %%
def vis (key_name,model_name, end_e):

    
    sp =60
    # =======  Open configuration file  ===============
    appliances = json.load(open("../conf/apps.json",'r'))
    
    nilmtk_key= appliances[key_name]['key']
    save_path ='../output/{}/{}'.format(model_name,key_name.replace('_',' '))
    v = appliances[key_name]
    data_path='/projects/da33/ozeidi/Project/data/UKDALE/ukdale.h5'
    #training_set = DataSet(data_path)
    validation_set = DataSet(data_path)

    disag_filename =  '{}/{}_disag-out_{}epochs.h5'.format(save_path,nilmtk_key,end_e) # The filename of the resulting datastore
    output = DataSet(disag_filename)

    val_builidng = v['validation_buildings'][0]


    validation_set.set_window(start=WINDOW_PER_BUILDING[val_builidng][0],end=WINDOW_PER_BUILDING[val_builidng][1])
    # This makes a list of references to the NILMTK main meters and submeter
    # no data is generated from them at this point
    mains = validation_set.buildings[val_builidng].elec.mains().power_series_all_data(sample_period=sp)
    meter= dict()
    meter['Pred'] = output.buildings[val_builidng].elec.submeters()[nilmtk_key].power_series_all_data(sample_period=sp)
    for key in allowed_key_names:
        k= appliances[key]['key']
        meter[k] = validation_set.buildings[val_builidng].elec.submeters()[k].power_series_all_data(sample_period=sp)

    # ------Plotting------------
    ax=[None]*6
    fig, ax = plt.subplots(6,1,sharex=True)
    fig.set_size_inches(7, 14)
    plt.xticks(rotation = 90)
    #main plot
    ax[0].plot(mains, label='Mains',color='red')
    ax[0].set_title('Mains Consumption')
    ax[0].set_ylabel('Power (W)')

    # submeter plot
    ax[1].plot( meter[nilmtk_key], label='Ground Truth', color ='green')
    ax[1].plot( meter['Pred'], label='Predicted', color = 'blue')
    ax[1].set_title('{} Predicted and GT'.format(key_name))
    ax[1].set_ylabel('Power (W)')
    for i,key in enumerate(set(allowed_key_names)-set([key_name])):
        i +=2
        k= appliances[key]['key']
        ax[i].plot(meter[k], label ='')
        ax[i].set_title(k)
        ax[i].set_ylabel('Power (W)')
    
    fig.legend(loc='best',fancybox=True, shadow=True, ncol=3)
    fig.suptitle("Comparison Plot",fontsize=14, fontweight='bold')

# %%
res =vis('dish_washer','Base_S2P',10)
# Out:
# /home/osal10/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: ResourceWarning: unclosed file <_io.TextIOWrapper name='../conf/apps.json' mode='r' encoding='UTF-8'>
# <img src="data:image/png;base64,..." width="700">
# /home/osal10/.local/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
res =vis('dish_washer','Base_S2P',10)
# Out:
# /home/osal10/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: ResourceWarning: unclosed file <_io.TextIOWrapper name='../conf/apps.json' mode='r' encoding='UTF-8'>
# <img src="data:image/png;base64,..." width="700">
# /home/osal10/.local/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
res =vis('kettle','Base_S2P_DOR10',60)
# Out:
# /home/osal10/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: ResourceWarning: unclosed file <_io.TextIOWrapper name='../conf/apps.json' mode='r' encoding='UTF-8'>
# <img src="data:image/png;base64,..." width="700">
# /home/osal10/.local/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
def vis_app (key_name, end_e):
    # =======  Open configuration file  ===============
    appliances = json.load(open("../conf/apps.json"))
    
    nilmtk_key= appliances[key_name]['key']
    v = appliances[key_name]
   
    
    
    save_path ='../output/{}'.format(key_name)
    disag_filename =  '{}/{}_disag-out_{}epochs.h5'.format(save_path,nilmtk_key,end_e) # The filename of the resulting datastore
    data_path='/projects/da33/ozeidi/Project/data/UKDALE/ukdale.h5'

    DS = DataSet(data_path)
    output = DataSet(disag_filename)
    buildings = v['train_buildings'] + v['validation_buildings']
    val_building = v['validation_buildings'][0]

    #mains = DS.buildings[val_builidng].elec.mains().power_series_all_data(sample_period=6)
    meter= dict()
    for i, b in enumerate(buildings):
        DS.set_window(start=WINDOW_PER_BUILDING[b][0],end=WINDOW_PER_BUILDING[b][1])
        meter[b] = DS.buildings[b].elec.submeters()[nilmtk_key].power_series_all_data(sample_period=6)
        

    # This makes a list of references to the NILMTK main meters and submeter
    # no data is generated from them at this point
    meter['Pred'] = output.buildings[val_building].elec.submeters()[nilmtk_key].power_series_all_data(sample_period=6)

    # ------Plotting------------
    ax=[None]*len(buildings)
    fig, ax = plt.subplots(len(ax),1,sharex=True)
    fig.set_size_inches(7, 14)
    plt.xticks(rotation = 90)
    # submeter plot
    ax[0].plot( meter[val_building], label='GT', color ='green')
    ax[0].plot( meter['Pred'], label='Predicted', color = 'blue')
    ax[0].set_title('{} Predicted and GT'.format(key_name))
    ax[0].set_ylabel('Power (W)')
    
    for i,k in enumerate(buildings[:-1]):
        i +=1
        ax[i].plot(meter[k], label ='')
        ax[i].set_title(k)
        ax[i].set_ylabel('Power (W)')
 
    fig.legend(loc='best',fancybox=True, shadow=True, ncol=3)
    fig.suptitle("Comparison Plot",fontsize=14, fontweight='bold')

# %%
vis_app('kettle',5)
# Out:
# /home/osal10/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: ResourceWarning: unclosed file <_io.TextIOWrapper name='../conf/apps.json' mode='r' encoding='UTF-8'>
#   This is separate from the ipykernel package so we can avoid doing imports until
# <img src="data:image/png;base64,..." width="700">
# /home/osal10/.local/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
def mains_vis ():
#     # =======  Open configuration file  ===============
#     appliances = json.load(open("../conf/apps.json"))
#     save_path ='../output/{}'.format(key_name)
    
#     nilmtk_key= appliances[key_name]['key']
#     v = appliances[key_name]
    data_path='/projects/da33/ozeidi/Project/data/UKDALE/ukdale.h5'
    #training_set = DataSet(data_path)
    validation_set = DataSet(data_path)

#     disag_filename =  '{}/{}_disag-out_{}epochs.h5'.format(save_path,nilmtk_key,end_e) # The filename of the resulting datastore
#     output = DataSet(disag_filename)

#     val_builidng = v['validation_buildings'][0]


#     validation_set.set_window(start=WINDOW_PER_BUILDING[val_builidng][0],end=WINDOW_PER_BUILDING[val_builidng][1])
    # This makes a list of references to the NILMTK main meters and submeter
    # no data is generated from them at this point
    #mains = validation_set.buildings[val_builidng].elec.mains().power_series_all_data(sample_period=6)
    meter= dict()
    #meter['Pred'] = output.buildings[val_builidng].elec.submeters()[nilmtk_key].power_series_all_data()
    for key in WINDOW_PER_BUILDING.keys():
        #k= appliances[key]['key']
        validation_set.set_window(start=WINDOW_PER_BUILDING[key][0],end=WINDOW_PER_BUILDING[key][1])

        meter[key] = validation_set.buildings[key].elec.mains().power_series_all_data(sample_period=6)

    # ------Plotting------------
    ax=[None]*6
    fig, ax = plt.subplots(6,1,sharex=True)
    fig.set_size_inches(7, 14)
    plt.xticks(rotation = 90)
    #main plot
#     ax[0].plot(mains, label='Mains',color='red')
#     ax[0].set_title('Mains Consumption')
#     ax[0].set_ylabel('Power (W)')

#     # submeter plot
#     ax[1].plot( meter[nilmtk_key], label='Ground Truth', color ='green')
#     ax[1].plot( meter['Pred'], label='Predicted', color = 'blue')
#     ax[1].set_title('{} Predicted and GT'.format(key_name))
#     ax[1].set_ylabel('Power (W)')
    for i,key in enumerate(WINDOW_PER_BUILDING.keys()):
        #i +=2
        #k= appliances[key]['key']
        ax[i].plot(meter[key], label ='')
        ax[i].set_title(key)
        ax[i].set_ylabel('Power (W)')
    
    fig.legend(loc='best',fancybox=True, shadow=True, ncol=3)
    fig.suptitle("Comparison Plot",fontsize=14, fontweight='bold')

# %%
mains_vis()
# Out:
# /home/osal10/.local/lib/python3.6/site-packages/nilmtk/utils.py:426: UserWarning: Found duplicate index. Keeping first value
#   warnings.warn("Found duplicate index. Keeping first value")
# <img src="data:image/png;base64,..." width="700">
# No handles with labels found to put in legend.
# /home/osal10/.local/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
def rearrange(cluster_centers, labels):
    centroids = cluster_centers.reshape(1,-1)[0]
    ix = np.argsort(centroids)
    #print(ix)
    lut= np.zeros_like(ix)
    lut[ix]=np.arange(1,len(centroids)+1)
    return (lut[labels])
#rearrang(clusterer.cluster_centers_,clusterer.labels_)

def cluster_series(clusterer, meter_series, on_threshold):
    onehot_encoder = OneHotEncoder(sparse=False)
    meter_series = meter_series.reshape(-1,1)
    ix = meter_series >=on_threshold
    cluster_labels = clusterer.predict(meter_series[ix].reshape(-1,1))
    
    cluster_labels = rearrange(clusterer.cluster_centers_, cluster_labels )
    print(set(cluster_labels))
    meter_series[ix]= cluster_labels

    meter_series[ix==False] = 0
    meter_series =  onehot_encoder.fit_transform(meter_series)
    return meter_series

def lut(clusterer):
    c= np.sort(clusterer.cluster_centers_)
    c = np.append(np.zeros(1),c)
    return c
# if __name__ == '__main__':
#     app='dish_washer'
#     clf =joblib.load('ShortSeq2Point/appconf/{}_clf.pkl'.format(app))
#     y_train = np.load("ShortSeq2Point/dataset/trainsets/Y-{}.npy".format(app))
#     res = cluster_series(clf, y_train,10)
#     print(res)

# %%
#from src.quantize import cluster_series
def vis(key_name, epoch):
    # =======  Open configuration file
    if (key_name not in allowed_key_names):
        print("    Device {} not available".format(key_name))
        print("    Available device names: {}", allowed_key_names)
    mains=None
    meter= dict()
    
    for key in allowed_key_names:
        conf_filename = "conf/apps.json"
        with open(conf_filename) as data_file:
            conf = json.load(data_file)
            conf= conf[key_name]
            input_window = conf['seq_length']
            threshold = conf['on_power_threshould']
            mamax = 5000
            memax = conf['max_power']
            #mean = conf['mean']
            #std = conf['std']
            train_buildings = conf['train_buildings']
            test_building = conf['test_building']
            meter_key = conf['key']

    conf_filename = "conf/{}.json".format(key_name)
    with open(conf_filename) as data_file:
        conf = json.load(data_file)

        input_window = conf['seq_length']
        threshold = conf['on_threshold']
        mamax = 5000
        memax = conf['memax']
        mean = conf['mean']
        std = conf['std']
        train_buildings = conf['train_buildings']
        test_building = conf['validation_buildings']
        on_threshold = conf['on_threshold']
        meter_key = conf['nilmtk_key']
        save_path = conf['save_path']
    pred=np.load("output/{0}/pred-{0}-epochs{1}.npy".format(key_name,epoch))
    pred = np.append(np.zeros(input_window), pred)
    print(pred.shape)
    clf = joblib.load('conf/{}_clf.pkl'.format(key_name))
    #state_lut = lut(clf)
    pred_state= cluster_series(clf, pred.copy(),on_threshold) 
    pred_state = np.array([ np.argmax(p) for p in pred_state])
    meter_state= cluster_series(clf, meter[key_name].copy(),on_threshold) 
    meter_state =  np.array([ np.argmax(p) for p in meter_state])
    #assert (len(pred) == len(meter))
    #print(' pred shape:{}, meter sahpe{}'.format(pred.shape, meter.shape))
   
    #------Plotting------------
    ax=[None]*4
    fig, ax = plt.subplots(6,1,sharex=True)
    fig.set_size_inches(7, 14)
    
    #main plot
    ax[0].plot(mains, label='Mains',color='red')
    ax[0].set_title('Mains Consumption')
    ax[0].set_ylabel('Power (W)')
    # submeter plot
    ax[1].plot( meter[key_name], label='Ground Truth')
    ax[1].plot( pred, label='Predicted')
    ax[1].set_title('{} Predicted and GT'.format(key_name))
    ax[1].set_ylabel('Power (W)')
    # State plot
    ax[2].plot( meter_state, label='GT State')
    ax[2].plot( pred_state, label='Pred State')
    ax[2].set_title('{} Predicted State and GT'.format(key_name))
    ax[2].set_ylabel('State')
    ax[2].yaxis.set_ticks(np.arange(min(meter_state), max(meter_state)+1 , 1.0))
    for i,key in enumerate(set(allowed_key_names)-set([key_name])):
        i +=3
        ax[i].plot(meter[key])
        ax[i].set_title(key)
        ax[i].set_ylabel('Power (W)')
#     #formating
#     ax1.set_title('Mains')
#     ax1.set_ylabel('Power (W)')
#     ax2.set_title('Submeter')
#     ax2.set_ylabel('Power (W)')

    fig.legend(loc='best',fancybox=True, shadow=True, ncol=3)
    fig.suptitle("Comparison Plot",fontsize=14, fontweight='bold')
#     #fig.autofmt_xdate()
#     #fig.savefig('output/{}_disag_plot'.format(k))
    plt.show()
#     return [pred,mains,meter]

# %%
vis('kettle', 5)
# Out:
# (86400,)
# {1}
# {1, 2}
# /home/osal10/.local/lib/python3.6/site-packages/numpy/matrixlib/defmatrix.py:68: PendingDeprecationWarning: the matrix subclass is not the recommended way to represent matrices or deal with linear algebra (see https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html). Please adjust your code to use regular ndarray.
#   return matrix(data, dtype=dtype, copy=False)
# <img src="data:image/png;base64,..." width="700">
# /home/osal10/.local/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
X_train = np.load("data/trainsets/X-{}.npy".format('kettle'))
Y_train = np.load("data/trainsets/Y-{}.npy".format('kettle'))

# %%
def vis_train(key_name):
    # =======  Open configuration file
    if (key_name not in allowed_key_names):
        print("    Device {} not available".format(key_name))
        print("    Available device names: {}", allowed_key_names)
    
    
    X_train = np.load("data/trainsets/X-{}.npy".format(key_name))
    Y_train = np.load("data/trainsets/Y-{}.npy".format(key_name))
    X_train = np.array([ i[0] for i in X_train]).reshape(-1)
    Y_train = Y_train.reshape(-1)
    #------Plotting------------
    fig, (ax1, ax2) = plt.subplots(2,1,sharex=True)
    fig.set_size_inches(7, 4)
    #main plot
    ax1.plot(X_train, label='Mains',color='red')
    # submeter plot
    ax2.plot( X_train, label='Main')
    ax2.plot( Y_train, label='Meter')

    #formating
    ax1.set_title('Mains')
    ax1.set_ylabel('Power (W)')
    ax2.set_title('Submeter')
    ax2.set_ylabel('Power (W)')
    
    fig.legend(loc='best',fancybox=True, shadow=True, ncol=3)
    fig.suptitle("Comparison Plot",fontsize=14, fontweight='bold')
    #fig.autofmt_xdate()
    #fig.savefig('output/{}_disag_plot'.format(k))
    plt.show()
    #return [pred,mains,meter]

# %%
vis_train('kettle')
# Out:
# <img src="data:image/png;base64,..." width="700">
# /home/osal10/.local/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
appliances = {
                'washing_machine':{'key':'washing machine',
                'seq_length':1024,
                'train_buildings' : [1, 5],
                'validation_buildings' : [2],
                'max_power':2500,
                'on_power_threshould': 20,
                'min_on_duration': 1800,
                'min_off_duration': 160, 
                'appliances':['washe dryer', 'washing machine']},

                'fridge':{'key':'fridge',
                'seq_length' : 512,
                'train_buildings' : [1, 4, 2],
                'validation_buildings' : [5],
                'max_power':300,
                'on_power_threshould': 50,
                'min_on_duration': 60,
                'min_off_duration': 12, 
                'appliances':['fridge freezer', 'fridge', 'freezer']},

                'kettle':{'key':'kettle',
                'seq_length':100,
                'train_buildings' : [1, 2 ,3, 4],
                'validation_buildings' : [5],
                'max_power':3100,
                'on_power_threshould': 2000,
                'min_on_duration': 12,
                'min_off_duration': 0, 
                'appliances':['kettle']},
                #seq_length':1024 + 512
                'dish_washer':{'key':'dish washer',
                'seq_length':1024+512,
                'train_buildings' : [1, 2],
                'validation_buildings' : [5],
                'max_power':2500,
                'on_power_threshould': 10,
                'min_on_duration': 1800,
                'min_off_duration': 1800, 
                'appliances':['dish washer']},


                'microwave':{'key':'microwave',
                'seq_length':288,
                'train_buildings' : [1, 2],
                'validation_buildings' : [5],
                'max_power':3000,
                'on_power_threshould': 200,
                'min_on_duration': 12,
                'min_off_duration': 30, 
                'appliances':['microwave']}}

json.dump(appliances, open('apps.json','w'))

# %%
apps =json.load(open('../conf/apps.json'))
apps['kettle']
# Out:
# {'key': 'kettle',
#  'seq_length': 100,
#  'train_buildings': [1, 2, 3, 4],
#  'validation_buildings': [5],
#  'max_power': 3100,
#  'on_power_threshould': 2000,
#  'min_on_duration': 12,
#  'min_off_duration': 0,
#  'appliances': ['kettle']}
